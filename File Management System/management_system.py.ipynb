# %%
import os

# %%
folderpath = r"/Users/helenamagaldi/Dropbox/My Mac (MacBook Pro de Helena)/Downloads"
os.chdir(folderpath)

# %%
os.getcwd()
# Out:
# '/Users/helenamagaldi/Dropbox/My Mac (MacBook Pro de Helena)/Downloads'

# %%
os.listdir()
# Out:
# ['Lógica de Programação - Portugol, UDemy-converted.pdf',
#  'Modulo_1.pptx',
#  'Manual de magia com as ervas by Bruno J. Gimenes, Patrícia Cândido [Bruno J. Gimenes, Patrícia Cândido] (z-lib.org).pdf',
#  'Photo on 2021-01-06 at 9.35 AM.jpg',
#  'CADASTRO AUTÔNOMOS_RPA (1).xlsx',
#  '66.Error+notes.html',
#  'Codigo Limpo - Completo PT_compressed_compressed.pdf',
#  'WhatsApp Unknown 2021-04-18 at 7.58.24 PM.zip',
#  'Tarefa de Casa - Módulo 2.ipynb',
#  'neo-javaee7-wp-sdk-1.84.6',
#  'GMT20210507-210223_Recording.m4a',
#  '0001 2.jpg',
#  'Machine Learning – Guia de Referência Rápida Trabalhando com dados estruturados em Python by Matt Harrison (z-lib.org).pdf',
#  'Helena #FORM 0623_Inclusão SPG.docx',
#  '1. Proposta de Prestaçao de Serviços Advocatícios IV em 9.6.21.pdf',
#  'GMT20210513-224730_Recording (1).m4a',
#  'TablePlus.dmg',
#  'GMT20210508-122342_Recording.txt',
#  '66.Error+notes (1).html',
#  'Confirmação de monitora - Plantão no Slack.docx',
# ...
